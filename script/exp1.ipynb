# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('~/medicare-project/data/pp_npi_13.tab', sep='\t')
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index([u'NPI', u'NPPES_PROVIDER_LAST_ORG_NAME', u'NPPES_PROVIDER_FIRST_NAME',
#        u'NPPES_PROVIDER_MI', u'NPPES_CREDENTIALS', u'NPPES_PROVIDER_GENDER',
#        u'NPPES_ENTITY_CODE', u'NPPES_PROVIDER_STREET1',
#        u'NPPES_PROVIDER_STREET2', u'NPPES_PROVIDER_CITY',
#        u'NPPES_PROVIDER_ZIP', u'NPPES_PROVIDER_STATE',
#        u'NPPES_PROVIDER_COUNTRY', u'SPECIALTY_DESC', u'DESCRIPTION_FLAG',
#        u'BENE_COUNT', u'TOTAL_CLAIM_COUNT', u'TOTAL_DRUG_COST',
#        u'TOTAL_DAY_SUPPLY', u'BENE_COUNT_GE65', u'BENE_COUNT_GE65_REDACT_FLAG',
#        u'TOTAL_CLAIM_COUNT_GE65', u'GE65_REDACT_FLAG', u'TOTAL_DRUG_COST_GE65',
#        u'TOTAL_DAY_SUPPLY_GE65', u'BRAND_CLAIM_COUNT', u'BRAND_REDACT_FLAG',
#        u'BRAND_CLAIM_COST', u'GENERIC_CLAIM_COUNT', u'GENERIC_REDACT_FLAG',
#        u'GENERIC_CLAIM_COST', u'OTHER_CLAIM_COUNT', u'OTHER_REDACT_FLAG',
#        u'OTHER_CLAIM_COST', u'MAPD_CLAIM_COUNT', u'MAPD_REDACT_FLAG',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1049381 entries, 0 to 1049380
# Data columns (total 46 columns):
# NPI                             1049381 non-null int64
# NPPES_PROVIDER_LAST_ORG_NAME    1049354 non-null object
# NPPES_PROVIDER_FIRST_NAME       1042614 non-null object
# NPPES_PROVIDER_MI               775539 non-null object
# NPPES_CREDENTIALS               1006429 non-null object
# NPPES_PROVIDER_GENDER           1042626 non-null object
# NPPES_ENTITY_CODE               1049381 non-null object
# NPPES_PROVIDER_STREET1          1049380 non-null object
# NPPES_PROVIDER_STREET2          439566 non-null object
# NPPES_PROVIDER_CITY             1049380 non-null object
# NPPES_PROVIDER_ZIP              1049380 non-null object
# NPPES_PROVIDER_STATE            1049381 non-null object
# NPPES_PROVIDER_COUNTRY          1049381 non-null object
# SPECIALTY_DESC                  1049381 non-null object
# DESCRIPTION_FLAG                1049381 non-null object
# ...

# %%
df.describe()
# Out:
#                 NPI     BENE_COUNT  TOTAL_CLAIM_COUNT  TOTAL_DRUG_COST  \
# count  1.049381e+06  905381.000000     1049381.000000   1049381.000000
# mean   1.499770e+09     143.220327        1303.850100     98739.983028
# std    2.879001e+08     182.636813        3151.892795    239065.735672
# min    1.003000e+09      11.000000          11.000000         0.000000
# 25%    1.245588e+09      31.000000          49.000000      1553.850000
# 50%    1.497978e+09      78.000000         183.000000      8999.200000
# 75%    1.740597e+09     191.000000         956.000000     80976.370000
# max    1.993000e+09   24164.000000      191530.000000  16602543.110000
#
#        TOTAL_DAY_SUPPLY  BENE_COUNT_GE65  TOTAL_CLAIM_COUNT_GE65  \
# count    1049381.000000    598228.000000           823082.000000
# mean       50160.206527       147.775632             1219.969788
# std       118671.790811       172.945464             2791.054295
# min           11.000000         0.000000                0.000000
# ...

# %%
df.shape
# Out:
# (1049381, 46)

# %%
df.head()
# Out:
#           NPI                  NPPES_PROVIDER_LAST_ORG_NAME  \
# 0  1447268107                         10 PARK PHARMACY INC.
# 1  1174856348  101 FAMILY MEDICAL GROUP,A PROFESSIONAL CORP
# 2  1720181522              154ST STREET MEDICAL PLAZA, INC.
# 3  1821285826                     21ST CENTURY ONCOLOGY LLC
# 4  1457520132                         3 SUNS INVESTMENT INC
#
#   NPPES_PROVIDER_FIRST_NAME NPPES_PROVIDER_MI NPPES_CREDENTIALS  \
# 0                       NaN               NaN               NaN
# 1                       NaN               NaN               NaN
# 2                       NaN               NaN               NaN
# 3                       NaN               NaN               NaN
# 4                       NaN               NaN               NaN
#
#   NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE     NPPES_PROVIDER_STREET1  \
# 0                   NaN                 O               53 E 34TH ST
# 1                   NaN                 O  22030 SHERMAN WAY STE 101
# ...

# %%
df_drug = pd.read_csv('pp_npi_drug_13.tab', sep='\t')

# %%
df_drug.shape
# Out:
# (23650520, 19)

# %%
df_drug.head()
# Out:
#           NPI    NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1821285826       21ST CENTURY ONCOLOGY LLC                       NaN
# 1  1093969024  A PRESTIGE WELLNESS CENTER, PA                       NaN
# 2  1518048750                         A VILES                      OMAR
# 3  1952310666                       A'BODJEDI                    ENENGE
# 4  1952310666                       A'BODJEDI                    ENENGE
#
#   NPPES_PROVIDER_CITY NPPES_PROVIDER_STATE      SPECIALTY_DESC  \
# 0            AVENTURA                   FL             Urology
# 1               DORAL                   FL   Internal Medicine
# 2             MINEOLA                   NY  Pediatric Medicine
# 3            STAMFORD                   CT          Psychiatry
# 4            STAMFORD                   CT          Psychiatry
#
#   DESCRIPTION_FLAG            DRUG_NAME         GENERIC_NAME  BENE_COUNT  \
# 0                S       TAMSULOSIN HCL       TAMSULOSIN HCL         NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined
