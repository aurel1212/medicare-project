# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_excel('/home/ubuntu/medicare-project/data/County_All_Table.xlsx', sheetname=2, header=1, na_values=['*', '.'])

# %%
df.head()
# Out:
#       State          County  State and County FIPS Code  \
# 0  National  NATIONAL TOTAL                         NaN
# 1        AK     STATE TOTAL                         NaN
# 2        AK       ANCHORAGE                        2020
# 3        AK          BETHEL                        2050
# 4        AK     BRISTOL BAY                        2060
#
#    Beneficiaries with Part A and Part B  FFS Beneficiaries  MA Beneficiaries  \
# 0                              43485208           32623343          10861865
# 1                                 56449              55763               686
# 2                                 22825              22532               293
# 3                                   671                671                 0
# 4                                   NaN                624               NaN
#
#    MA Participation Rate  Average Age  Percent Female  Percent Male  \
# 0                  24.98           72           55.88         44.12
# ...

# %%
for i in df.columns:
    print i
# Out:
# State
# County
# State and County FIPS Code
# Beneficiaries with Part A and Part B
# FFS Beneficiaries
# MA Beneficiaries
# MA Participation Rate
# Average Age
# Percent Female
# Percent Male
# Percent Non-Hispanic White
# Percent African American
# Percent Hispanic
# Percent Other/Unknown
# Percent Eligible for Medicaid
# Average HCC Score
# Total Actual Costs
# Total Standardized Costs
# Total Standardized Risk-Adjusted Costs
# Actual Per Capita Costs
# Standardized Per Capita Costs
# Standardized Risk-Adjusted Per Capita Costs
# IP Actual Costs
# IP Actual Costs as % of Total Actual Costs
# IP Per Capita Actual Costs
# IP Per User Actual Costs
# IP Standardized Costs
# IP Standardized Costs as % of Total Standardized Costs
# IP Per Capita Standardized Costs
# IP Per User Standardized Costs
# IP Users (with a covered stay)
# % of Beneficiaries Using IP
# IP Covered Stays Per 1000 Beneficiaries
# IP Covered Days Per 1000 Beneficiaries
# PAC: LTCH Actual Costs
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3191 entries, 0 to 3190
# Columns: 243 entries, State to PQI16 Lower Extremity Amputation Admission Rate (age 75+)
# dtypes: float64(241), object(2)
# memory usage: 5.9+ MB

# %%
df.describe().T
# Out:
#                                                     count          mean  \
# State and County FIPS Code                           3136  3.043361e+04
# Beneficiaries with Part A and Part B                 3128  4.150664e+04
# FFS Beneficiaries                                    3187  3.064514e+04
# MA Beneficiaries                                     3128  1.029092e+04
# MA Participation Rate                                3128  1.563976e+01
# Average Age                                          3187  7.153938e+01
# Percent Female                                       3185  5.473398e+01
# Percent Male                                         3185  4.526610e+01
# Percent Non-Hispanic White                           1717  8.594384e+01
# Percent African American                             1717  8.108492e+00
# Percent Hispanic                                     1717  3.643768e+00
# Percent Other/Unknown                                1717  2.303949e+00
# ...
